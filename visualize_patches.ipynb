# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
from torchvision import transforms
import matplotlib.pyplot as plt

from utils import *

# %%
transform = transforms.Compose(
    [transforms.ToTensor()])

trainset = torchvision.datasets.CIFAR10(root='./cifar_data', train=True,
                                        download=True, transform=transform)
num_classes = len(trainset.classes)

# %%
og_image = []
patchified_set = []
labels = []

for i in trainset:
    og_image.append(i[0])
    patches = patch_generator(i[0], 16, viz_mode = True)
    labels.append(i[1])
    patchified_set.append(patches)

# %%
og_image = torch.stack(og_image, dim = 0)

# %%
len(patchified_set), len(og_image)
# Out:
# (50000, 50000)

# %%
plt.imshow(og_image[220].permute(1,2,0).detach().numpy())
plt.show()

# %%
i = patchified_set[220]
for patch in i:
    plt.imshow(torch.tensor(patch).permute(1,2,0).detach().numpy())
    plt.show()
